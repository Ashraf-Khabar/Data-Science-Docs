# %% [markdown]
# ## Functions - Achraf khabar
#
# A function is defined as a relation between a set of inputs having one output each .
#
# $\mathrm{E}\longrightarrow \mathrm{E}
# x \longrightarrow f(x)$
#
# For example :
#
# $\mathbb{R}\longrightarrow \mathbb{R}^+ \\
# x \longrightarrow \sqrt{x}$
#
# **noted that :** $\mathbb{R}^*$ is the set $\mathbb{R}$ but only positive numbers starting from the $0$ .

# %% [markdown]
# #### Functions in python :

# %%
import numpy as np

# %%
def sqrt(x):
    return np.sqrt(x)

# %%
sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# We can plot this function, first we need the define two axes, $x$ axe for all numbers we want to plot, and for each number we have the image associated of it in the $y$ axe .

# %%
# define the numbers using number and store in a vector named x
x = np.linspace(0, 10) # we will calculate the square root of the numbers from 0 to 10
# Calculating the square root of each x and store it in a vector named y : 
y = sqrt(x)

# %%
# Ploting this need a lybrary named mathplotlib : 
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)

# %% [markdown]
# We can define other functions like $sin(x)$, $cos(x)$, ... or other complicated functions too

# %%
def FUNCTION(x, y):
    return np.sin(2 * np.pi + x) + np.cos(y + x) + np.sin(y * np.pi)

# %%
print(FUNCTION(1, 2))
print(FUNCTION(2, 3))
print(FUNCTION(3, 4))
print(FUNCTION(4, 5))
print(FUNCTION(5, 6))
print(FUNCTION(6, 7))
# Out:
# -0.14852151179254927
# 1.1929596122889086
# 0.8950222624031716
# -1.6679327571926044
# -0.9544985766750885
# 0.628031283251271

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
Z = FUNCTION(X, Y)

plt.contourf(X, Y, Z, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Function Plot')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Function Plot')
plt.show()

# %% [markdown]
# # Derivatives :

# %% [markdown]
# * The notion of derivative is the rate of develpoement of function $f(x)$ in function of times .
# * We can name this the **The rate of developement** and we ca nreprensente it as : $\mathrm{T}_{a,b} = \frac{f(a)-f(b)}{a-b}$ , and we have 3 cases :
#     * if $\mathrm{T}_{a,b} > 0$ means that the function groghs by time .
#     * if $\mathrm{T}_{a,b} < 0$ means that the function decrease by time .
#     * if $\mathrm{T}_{a,b} = 0$ means this function is a constant .

# %% [markdown]
# For example we have the function :
#
# $\mathbb{R}^+ \longrightarrow \mathbb{R} \\ f(x)\longrightarrow 2x+ \sqrt{x+2}$
#
# and you're calculating the quotient $\mathrm{T}_{a,b} = \frac{f(a)-f(b)}{a-b}$ Simplifying the expression as you did :
#
# $\mathrm{T}_{a,b} = \frac{f(a)-f(b)}{a-b} \\
# \Leftrightarrow \mathrm{T}_{a,b} = \frac{2a+\sqrt{a+2}-2b-\sqrt{b+2}}{a-b} \\\Leftrightarrow
# \mathrm{T}_{a,b}  = 2+ \frac{\sqrt{a+2}+\sqrt{b+2}}{a-b}$
#
# in pointing out that the sign of $\mathrm{T}_{a,b}$ depends on the sign of the second term $\frac{\sqrt{a+2}+\sqrt{b+2}}{a-b}$ .
#
# Now, you've analyzed the signs correctly for the case when $a < b$ :
#
# * Since $a < b$, the denominator $a-b$ is negative .
# * Both $\sqrt{a + 2}$ and $\sqrt{b+2}$ are positive since they onvolve square toots of positives numbers .
# * The sum $\sqrt{a+2} + \sqrt{b+2}$ is positive because each term is positive .
#
# So, you have a positive numerator and a negative denominator, resulting in a negative overall value for $\mathrm{T}_{a,b}$. for $a <b$ .

# %%
# Implements the Tab in python : 
def f(x):
    return 2*x + np.sqrt(x + 2)

def Tab(a, b): 
    return (f(a) - f(b)) / (a - b)

# %%
# Generate arrays a and b
a = np.linspace(0.01, 10, 100)  # Avoid division by zero by starting from a small value
b = np.linspace(0.02, 10, 100)  # Offset b slightly from a to avoid division by zero

# Calculate Tab values for corresponding a and b
y = Tab(a, b)

# Plot the results
plt.plot(a, y)
plt.xlabel('a')
plt.ylabel('Tab(a, b)')
plt.title('Tab function')
plt.show()
# Out:
# c:\Users\ashraf\anaconda3\envs\testenvironment\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# The $T_{a,b}$ gives a clear idea about the behviour of our function, but we cannot calculate the derivative of the function for each time we want to studie the behaviour of our function .
#
# We need to introduce a new guest named **Deriviative** :
#
# $\mathbb{E} \longrightarrow \mathbb{F}
# \\
# f(x)\longrightarrow  f'(x)$ and $x^{'} = 1$.

# %% [markdown]
# ### Example of derivativ functions :
#
# * The function here is $f(x) = x$ :
#
# | Function         | Derivative                |
# |------------------|---------------------------|
# | $f(x) = x$       | $f'(x) = 1$               |
# | $f(x) = x^n$     | $f'(x) = n\cdot x^{n-1}$  |
# | $g(x) = \sin(x)$ | $g'(x) = \cos(x)$         |
# | $h(x) = \cos(x)$ | $h'(x) = -\sin(x)$        |
# | $p(x) = e^x$     | $p'(x) = e^x$             |
# | $q(x) = \ln(x)$  | $q'(x) = \frac{1}{x}$     |
# | $r(x) = \sqrt{x}$| $r'(x) = \frac{1}{2\sqrt{x}}$ |
# | $s(x) = \tan(x)$ | $s'(x) = \sec^2(x)$       |
# | $c(x) = \cot(x)$ | $c'(x) = -\csc^2(x)$      |
# | $a(x) = \sec(x)$ | $a'(x) = \sec(x)\tan(x)$  |
# | $d(x) = \csc(x)$ | $d'(x) = -\csc(x)\cot(x)$ |
#
# * The function here $f(u(x))$ :
#
# | Function             | Derivative                                      |
# |----------------------|-------------------------------------------------|
# | $f(u) = u^n$         | $f'(u) = n \cdot u^{n-1} \cdot u'(x)$           |
# | $g(u) = \sin(u)$     | $g'(u) = \cos(u) \cdot u'(x)$                   |
# | $h(u) = \cos(u)$     | $h'(u) = -\sin(u) \cdot u'(x)$                  |
# | $p(u) = e^u$         | $p'(u) = e^u \cdot u'(x)$                       |
# | $q(u) = \ln(u)$      | $q'(u) = \frac{1}{u} \cdot u'(x)$               |
# | $r(u) = \sqrt{u}$    | $r'(u) = \frac{1}{2\sqrt{u}} \cdot u'(x)$       |
# | $s(u) = \tan(u)$     | $s'(u) = \sec^2(u) \cdot u'(x)$                 |
# | $c(u) = \cot(u)$     | $c'(u) = -\csc^2(u) \cdot u'(x)$                |
# | $a(u) = \sec(u)$     | $a'(u) = \sec(u)\tan(u) \cdot u'(x)$            |
# | $d(u) = \csc(u)$     | $d'(u) = -\csc(u)\cot(u) \cdot u'(x)$           |

# %% [markdown]
# The $f'(x)$ give us a clear idea about the bahviour of the function .
#
# let take the same previous example : $f(x) = 2x+ \sqrt{x+2}$ , and calculating the $f'(x)$ .
#
# We have that:
# * $\text{cst}' = 0$ for example $2' = 0$ .
# * $(u(x) \times v(x))' = u(x)'.v(x) + u(x).v'(x) $ .
# * $(\frac{u(x)}{v(x)})' = \frac{u(x)v'(x) - v'(x)u(x)}{u(x)^2}$ .
# * $(u(x) + v(x))' = u'(x) + v'(x)$.
#
# Using the prevIous rules, we got : $f'(x) = (2x)' + (\sqrt{x+2})'$ ,let's caclulate the $f'(x) : $
#
# * $f'(x) = (2x)' + \frac{1}{2\sqrt{2+x}} \cdot (2 + x)' = 2 + \frac{1}{2\sqrt{2+x}}$ .

# %%
# Let's see this in python : 
def der_f(x):
    return 2 + 1/(2* np.sqrt(2+x))

# %%
x = np.linspace(0.01, 10, 100)
y = der_f(x)

# Plot the results
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("f'(x) function")
plt.show()

# %% [markdown]
# We can see clearnlly that we got the same result as $\text{T}_{a,b}$ .

# %%
x_axes = np.linspace(0.01, 10, 100)
y1 = f(x_axes)
y2 = der_f(x_axes)

plt.plot(x_axes, y1, 'r')
plt.plot(x_axes, y2, 'b')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("f'(x) function")
plt.show()

# %% [markdown]
# There other notation for the derivative function : $\frac{d f(x)}{dx}$, means that we will derivate and $x$ is the variable . This can behave as fraction too, for example :
# $\frac{d f(x)}{dx} = g(x) \Leftrightarrow d f(x) = g(x)\cdot dx$ .

# %% [markdown]
# ### Now we will use a module named **sympy** to use maths function and derivative functions :

# %%
# Let's create a a symbols to simplify the use of function : 
from sympy import *
x = symbols('x')

# %%
x #Now we have the symbole
# Out:
# x

# %%
# If we write : 
x**2 + 3
# Out:
# x**2 + 3

# %% [markdown]
# Derivative function using **sympy** :

# %%
# let's create a symbole : 
x = symbols('x')
# Let's create the function : 
f = 2*x + sqrt(x + 2) #The same function we used to use (sqrt is a mthod in sympy)

# %%
# define the derivative function : 
df = diff(f, x) #The diff function calculate the derivative function .

# %%
df # We got the same result as before
# Out:
# 2 + 1/(2*sqrt(x + 2))

# %% [markdown]
# How to evaluate the function of derivative : $f'(x)$ , for example testing the value of $f'(2), f'(3), ...$ .

# %%
value1 = 2
value2 = 3

print(f"f'({value1}) = {df.subs(x, value1)}")
print(f"f'({value2}) = {df.subs(x, value2)}")
# Out:
# f'(2) = 9/4
# f'(3) = sqrt(5)/10 + 2

# %% [markdown]
# Let see how to make our **function** as `f(input)` :

# %%
# We will use the functtion of sympy named lamdify
f = lambdify(x, f)
df = lambdify(x, df)

# %%
f(3)
# Out:
# 8.23606797749979

# %%
value1 = 2
value2 = 3

print(f"f'({value1}) = {df(value1)}")
print(f"f'({value2}) = {df(value2)}")
# Out:
# f'(2) = 2.25
# f'(3) = 2.223606797749979

# %%
# Let's plot this function : 

y = df(x_axes)

plt.plot(x_axes, y) 
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("f'(x) function")
plt.show()

# %% [markdown]
# We got the same graphe as usual .

# %% [markdown]
# ### Functions of multiple variables :

# %% [markdown]
# We have ther types of function named functions of multiple varibales, wich means that instead of having $x$ as a variavle, we have $x_1, x_2, x_3, ...., x_4$ :
#
# $\mathbb{E}^n\longrightarrow \mathbb{E}^m \\
# (x_1, x_2,...,x_n) \longrightarrow f(x_1,x_2,...,x_n)$
#
# We can do the same thing we did with the functions $f(x)$ .

# %%
def function_2(x, y):
    return (2/3*x) + 2*y

def function_3(x, y, z):
    return (2 + 2*x)/(z+y)

# %%
function_2(2, 6)
# Out:
# 13.333333333333334

# %%
function_3(2, 4, 4)
# Out:
# 0.75

# %% [markdown]
# We can use **sympy** for this too :

# %%
x, y, z = symbols('x y z')

# %%
g = x*2 + pi*sin(2 * y) + 1/z
g
# Out:
# 2*x + pi*sin(2*y) + 1/z

# %% [markdown]
# ## The derivative in function with multiple variables :

# %% [markdown]
# The function $f(x_1, x_2, ..., x_n)$ deponds on multiple variables, let's introduce the partial derivative operator $\partial$, means we calculate the derivative of the function deponds on a paramter $x_1$ and others constants $(x_2, ..., x_n)$ .

# %% [markdown]
# let's take an example : $f(x, y, z) = 2x + \pi \sin(2y) + \frac{1}{z}$ , we have tree contities to calculate : $\frac{\partial f(x, y, z)}{\partial x}$, $\frac{\partial f(x, y, z)}{\partial y}$ and $\frac{\partial f(x, y, z)}{\partial z}$ .
#
# We introduce the $\overrightarrow{\mathrm{grad}}(f(x, y, z))$ which a vector of derivatives, we note also $\overrightarrow{\nabla}(f(x,y,z))$, and $\overrightarrow{\nabla} f = \left( \frac{\partial f(x, y, z)}{\partial x} , \frac{\partial f(x, y, z)}{\partial y} , \frac{\partial f(x, y, z)}{\partial z} \right)$ .

# %%
g_x = diff(g, x)
g_y = diff(g, y)
g_z = diff(g, z)

# %%
print(f"df(x, y, z)/dx = {g_x}")
print(f"df(x, y, z)/dy = {g_y}")
print(f"df(x, y, z)/dz = {g_z}")
# Out:
# df(x, y, z)/dx = 2
# df(x, y, z)/dy = 2*pi*cos(2*y)
# df(x, y, z)/dz = -1/z**2

# %%
grad = np.array([
    g_x,
    g_y,
    g_z
])

# %%
grad
# Out:
# array([2, 2*pi*cos(2*y), -1/z**2], dtype=object)

# %% [markdown]
# # Applications :

# %% [markdown]
# 1 - Write a function that takes a 3 parameters  of quadratic function to plot

# %% [markdown]
# Quadratic function : $ax^2 + bx + c$ .

# %%
def QFP(a, b, d):
    x = np.linspace(-50, 50)
    y = a * x**2 + b * x + d
    plt.plot(x, y, 'r')
    plt.title("Quadratic function")

def QFDP(a, b, d):
    x = np.linspace(-50, 50)
    y = a * 2 * x + b
    plt.plot(x, y, 'g')
    plt.title("Derivative of quadratic function")

# %%
for i in range(50):
    QFP(i, i+1, i+2)

# %%
QFP(1, 7, 0)
QFDP(1, 7, 0)

# %% [markdown]
# 2 - We need a function that change the frequance of periodic function :

# %%
def PF(empl = 1, freq = 1, color = 'b'):
    x = np.linspace(-np.pi, np.pi, 100)  
    y = empl * np.sin(np.pi * freq * x) 
    plt.plot(x, y, c=color)
    plt.title('Plot of PF Function')
    plt.show()

# %%
PF(1, 5)
PF(2, 8, 'r')
PF(15, 9, 'g')
PF()
